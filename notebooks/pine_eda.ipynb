# %%
import numpy as np
import pandas as pd

# %%
filepath = '../data/gbif/scotch_pine_kampinos/gbif_scotch_pine_040925/occurrence.txt'
df = pd.read_csv(filepath, sep='\t', low_memory=False)

# %%
df
# Out:
#          gbifID  accessRights  bibliographicCitation  language       license  \
# 0    5087226593           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1    5087212075           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2    5087196217           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3    5086907177           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4    5077151771           NaN                    NaN       NaN  CC_BY_NC_4_0
# ..          ...           ...                    ...       ...           ...
# 685  3384277655           NaN                    NaN       NaN     CC_BY_4_0
# 686  3384081517           NaN                    NaN       NaN     CC_BY_4_0
# 687  3355491052           NaN                    NaN       NaN     CC_BY_4_0
# 688  3355124751           NaN                    NaN       NaN  CC_BY_NC_4_0
# 689  2901513790           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#                  modified  publisher  \
# ...
